# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import json

import numpy as np
import matplotlib.pyplot as plt

# %%
# %autoreload now

# %%
from kaggle_vascular_competition.data_loaders import load_image, load_polygons
from kaggle_vascular_competition.params import paths
from kaggle_vascular_competition.plot import plot_image

# %%
image_id = 'faa10f94f96b'

# %%
plot_image(image_id, 'train')
